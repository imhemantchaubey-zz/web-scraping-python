# %% [markdown]
# Hello everyone...
# This is Hemant Chaubey here...
# This is the demo code for web scraping using python...
# Here, I have extracted the data from three websites...

# %%
print("Hello...I am Hemant Chaubey!")
# Out:
# Hello...I am Hemant Chaubey!

# %%
! pip install beautifulsoup4
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
! pip install requests
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import sys
import time
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
try:
    page=requests.get('https://www.amazon.in/Apple-iPhone-11-Pro-256GB/product-reviews/B07XVMJF2D/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews')                             # this might throw an exception if something goes wrong.
    
except Exception as e:
    error_type, error_obj, error_info = sys.exc_info()
    print ('ERROR FOR LINK:',url)
    print (error_type, 'Line:', error_info.tb_lineno)
                                                 
time.sleep(2)
soup=BeautifulSoup(page.text,'html.parser')
links=soup.find_all('div',attrs={'class':'a-size-base'})

# %%
page
# Out:
# <Response [200]>

# %%
links
# Out:
# [<div class="a-row a-spacing-large celwidget reviews-sort-filter a-size-base" id="cm_cr-view_opt_search"><div class="a-column a-span6 a-spacing-none reviews-search-section"><div class="a-fixed-right-grid reviews-search" data-reftag="cm_cr_arp_d_viewopt_kywd"><div class="a-fixed-right-grid-inner" style="padding-right:78px"><div class="a-fixed-right-grid-col a-col-left" style="padding-right:3.5%;float:left;"><span class="a-declarative" data-action="reviews:search-textbox" data-csa-c-func-deps="aui-da-reviews:search-textbox" data-csa-c-type="widget" data-reviews:search-textbox="{}"><div class="a-search a-span12"><i class="a-icon a-icon-search"></i><input class="a-input-text a-span12" id="filterByKeywordTextBox" maxlength="300" placeholder="Search customer reviews" type="search"/></div></span></div><div class="a-fixed-right-grid-col a-col-right" style="width:78px;margin-right:-78px;float:left;"><span class="a-declarative" data-action="reviews:search-button" data-csa-c-func-deps="aui-da-r
# ...

# %%
for i in links:
  print(i.text)
  print("\n")
# Out:
# Search
#
#
# Sort byTop reviewsMost recentTop reviewsFilter byAll reviewersVerified purchase onlyAll reviewersAll stars5 star only4 star only3 star only2 star only1 star onlyAll positiveAll criticalAll starsAll text, image and video reviewsImage and video reviews onlyAll text, image and video reviews
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                         1,348 total ratings, 353 with reviews
#
#
#
#
#
#
#
#
#
#
#
# There was a problem filtering reviews right now. Please try again later.
#
#
#
#
#
#
#
#
# From India
# Soumyajit Dey5.0 out of 5 stars
# BEST PHONE in the SmartPhone Market..........Hands'Down
# Reviewed in India on 16 September 2019
# ...

# %%
try:   
    page=requests.get('https://www.cricbuzz.com/')                             # this might throw an exception if something goes wrong.
    
except Exception as e:                                   
    error_type, error_obj, error_info = sys.exc_info()     
    print ('ERROR FOR LINK:',url)                          
    print (error_type, 'Line:', error_info.tb_lineno)      
                                                 
time.sleep(2)   
soup=BeautifulSoup(page.text,'html.parser')
summary=soup.find_all('div',attrs={'class':'cb-nws-intr'})

# %%
page
# Out:
# <Response [200]>

# %%
summary
# Out:
# [<div class="cb-nws-intr">While Van der Dussen hit a ton, Markram and Malan made 50s</div>,
#  <div class="cb-nws-intr">Pakistan lost the wicket of Babar at the fag end of the day</div>,
#  <div class="cb-nws-intr">The bidding closed on Wednesday (13 July) with 29 Expressions of Interests, but it was the IPL investment that dominated the franchise auction</div>,
#  <div class="cb-nws-intr">The BCCI is trying to negotiate with the Government of India over the matter so that the income from the tournament, to be distributed among the members of the ICC, is not severely affected</div>,
#  <div class="cb-nws-intr">In the run chase of 174, Ireland were bowled out for just 142</div>,
#  <div class="cb-nws-intr">It was India's first century partnership against England in England for the fifth wicket in nearly 8 years, effectively sealing the chase</div>,
# ...

# %%
for i in summary:
  print(i.text)
  print("\n")
# Out:
# While Van der Dussen hit a ton, Markram and Malan made 50s
#
#
# Pakistan lost the wicket of Babar at the fag end of the day
#
#
# The bidding closed on Wednesday (13 July) with 29 Expressions of Interests, but it was the IPL investment that dominated the franchise auction
#
#
# The BCCI is trying to negotiate with the Government of India over the matter so that the income from the tournament, to be distributed among the members of the ICC, is not severely affected
#
#
# In the run chase of 174, Ireland were bowled out for just 142
#
#
# It was India's first century partnership against England in England for the fifth wicket in nearly 8 years, effectively sealing the chase
#
#
# RCA is supposed to be a major step in decentralization of cricket at an administrative level and grassroots, which will have a significant impact on the overall growth of the sport in Bangladesh
#
#
# ...

# %%
try:   
    page=requests.get('https://gaana.com/')                             # this might throw an exception if something goes wrong.
    
except Exception as e:                                   
    error_type, error_obj, error_info = sys.exc_info()     
    print ('ERROR FOR LINK:',url)                          
    print (error_type, 'Line:', error_info.tb_lineno)      
                                                 
time.sleep(2)   
soup=BeautifulSoup(page.text,'html.parser')
songs=soup.find_all('a',attrs={'class':'al t_over'})

# %%
page
# Out:
# <Response [200]>

# %%
songs
# Out:
# [<a alt="Dil" class="al t_over" href="/song/dil-from-ek-villain-returns" title="Dil"> <!-- -->Dil</a>,
#  <a alt="Peaches" class="al t_over" href="/song/peaches-520" title="Peaches"> <!-- -->Peaches</a>,
#  <a alt="Left and Right (Feat. Jung Kook of BTS)" class="al t_over" href="/song/left-and-right-feat-jung-kook-of-bts" title="Left and Right (Feat. Jung Kook of BTS)"> <!-- -->Left and Right (Feat. Jung Kook of BTS)</a>,
#  <a alt='Kesariya (From "Brahmastra")' class="al t_over" href="/song/kesariya-from-brahmastra" title='Kesariya (From "Brahmastra")'> <!-- -->Kesariya (From "Brahmastra")</a>,
#  <a alt="Nakhre" class="al t_over" href="/song/nakhre-114" title="Nakhre"> <!-- -->Nakhre</a>,
#  <a alt="hope" class="al t_over" href="/song/hope-2737" title="hope"><span class="eicon"></span> <!-- -->hope</a>,
#  <a alt="Kitni Haseen Hogi" class="al t_over" href="/song/kitni-haseen-hogi-from-hit-the-first-" title="Kitni Haseen Hogi"> <!-- -->Kitni Haseen Hogi</a>,
# ...

# %%
for i in songs:
  print(i.text)
# Out:
#  Dil
#  Peaches
#  Left and Right (Feat. Jung Kook of BTS)
#  Kesariya (From "Brahmastra")
#  Nakhre
#  hope
#  Kitni Haseen Hogi
#  SYL
#  Gimmie The Loot
#  Galliyan Returns
#  Mutiyare Ni
#  Hot Shit (feat. Kanye West & Lil Durk)
#  Shringaar
#  Lemonade
#  Somebody Like U
#  Fitoor
#  Call
#  Why Can't You Wait
#  Shaamat
#  Tu Jinna Karda Ae
#  2step (feat. Armaan Malik)
#  Baarishon Mein
#  Red Chilli
#  changes
#  Tur Kalleyan
#  Ego
#  Numb
#  Iss Baarish Mein
#  Meri Maa - A Tribute To Legend Sidhu Moosewala
#  Drool
#  Kesariya (From "Brahmastra")
#  Drive Thru
#  Breezy (Deluxe)
#  Laal Singh Chaddha
#  Ki Ho Gaya
#  CLOSURE / CONTINUATION
#  Ek Villain Returns
#  Diamond Necklace - 1 Min Music
#  Walkerverse, Pt. I
#  Balma (feat. Aastha Gill)
#  Mella
#  The Way That Lovers Do
#  Mehram (From "Dr. Arora")
#  That Girl
#  Harry's House
#  Hit - The First Case
#  Kudi Kmaal
#  So Far So Good
#  Baarishon Mein
#  Nakhre
#  Come Home The Kids Miss You
# ...
